# %%
import pandas as pd
import numpy as np
import os

# %%
# Define path

# %%
path = r'C:\Users\Andrew\Desktop\Data Immersion 1\Instacart Basket Analysis'

# %%
# Import orders_products_merged

# %%
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'orders_products_merged.pkl'))

# %%
# Create df of first 1,000,000 rows

# %%
df = ords_prods_merged[:1000000]

# %%
# Check shape

# %%
df.shape
# Out:
# (1000000, 16)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                      2                  8
# 1   2398795        1             2                      3                  7
# 2    473747        1             3                      3                 12
# 3   2254736        1             4                      4                  7
# 4    431534        1             5                      4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
df.groupby('product_name')

# %%
# Get the mean using the agg function

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Get the mean bypassing the agg function

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# Try using agg to perform multiple functions

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Create a max order column, which is grouped by the user id, then find the max orders using the order number column

# %%
ords_prods_merged.head(15)
# Out:
#     order_id  user_id  order_number  order_day_of_the_week  order_hour_of_day  \
# 0    2539329        1             1                      2                  8
# 1    2398795        1             2                      3                  7
# 2     473747        1             3                      3                 12
# 3    2254736        1             4                      4                  7
# 4     431534        1             5                      4                 15
# 5    3367565        1             6                      2                  7
# 6     550135        1             7                      1                  9
# 7    3108588        1             8                      1                 14
# 8    2295261        1             9                      1                 16
# 9    2550362        1            10                      4                  8
# 10   2968173       15            15                      1                  9
# ...

# %%
# Try and see the first 100 rows

# %%
ords_prods_merged.head(100)
# Out:
#     order_id  user_id  order_number  order_day_of_the_week  order_hour_of_day  \
# 0    2539329        1             1                      2                  8
# 1    2398795        1             2                      3                  7
# 2     473747        1             3                      3                 12
# 3    2254736        1             4                      4                  7
# 4     431534        1             5                      4                 15
# ..       ...      ...           ...                    ...                ...
# 95   3226575      360             1                      5                 12
# 96   1469869      377             3                      5                 17
# 97   1927023      387             2                      4                 10
# 98    858092      420             4                      1                 19
# 99    119314      420             5                      3                 19
#
# ...

# %%
# adjust max number of rows to be shown

# %%
pd.options.display.max_rows = None

# %%
# Try displaying 100 again

# %%
ords_prods_merged.head(100)
# Out:
#     order_id  user_id  order_number  order_day_of_the_week  order_hour_of_day  \
# 0    2539329        1             1                      2                  8
# 1    2398795        1             2                      3                  7
# 2     473747        1             3                      3                 12
# 3    2254736        1             4                      4                  7
# 4     431534        1             5                      4                 15
# 5    3367565        1             6                      2                  7
# 6     550135        1             7                      1                  9
# 7    3108588        1             8                      1                 14
# 8    2295261        1             9                      1                 16
# 9    2550362        1            10                      4                  8
# 10   2968173       15            15                      1                  9
# ...

# %%
# Set flags using loc function

# %%
ords_prods_merged.loc[ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merged.loc[(ords_prods_merged['max_order'] <= 40) & (ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merged.loc[ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check values

# %%
ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Check the first 60 rows only using the columns you need by adjusting the head function

# %%
ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %%
ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared data', 'orders_products_merged.pkl'))

# %%
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                      2                  8
# 1   2398795        1             2                      3                  7
# 2    473747        1             3                      3                 12
# 3   2254736        1             4                      4                  7
# 4    431534        1             5                      4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...
